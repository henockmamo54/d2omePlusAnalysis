# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %%
path= 'C:/Workplace/C++/d2ome_v2/v2/v2/bin/Debug'
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)

# %%
data=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    data=pd.concat([data,d])
# data=data[data.NDP >=4]
print(data.shape)
data.head()
# Out:
# (32620, 14)
#    proteinName           peptideSeq  old_Rsquared  new_Rsquared  NDP  \
# 0  1433B_MOUSE           DSTLImQLLR      0.405407      0.842207    8
# 1  1433B_MOUSE       AVTEQGHELSNEER     -0.515961     -0.132980    7
# 2  1433B_MOUSE     LAEQAERYDDMAAAMK     -0.067008      0.388974    5
# 3  1433B_MOUSE  TAFDEAIAELDTLNEESYK      0.937993      0.978693    8
# 4  1433B_MOUSE  TAFDEAIAELDTLNEESYK      0.636834      0.973459    9
#
#    rateconstant     sigma     Abundance  MassToCharge      RMSE  \
# 0       0.63353  0.500928  1.913215e+07     603.33154  0.109762
# 1       0.47244  0.510142  4.919352e+07     533.58502  0.241501
# 2       0.13982  0.087811  1.312825e+08     906.91638  0.086949
# 3       0.39895  0.039049  1.747170e+07    1080.00488  0.016933
# 4       0.27219  0.065604  2.121646e+07     720.33905  0.047914
#
#    selected_A1A0_count   selected_A2A0_count   selected_A2A1_count  \
# 0                  1.0                   3.0                   1.0
# 1                  2.0                   1.0                   4.0
# 2                  3.0                   0.0                   0.0
# 3                  3.0                   1.0                   3.0
# 4                  2.0                   1.0                   1.0
#
#        Protein
# 0  1433B_MOUSE
# 1  1433B_MOUSE
# 2  1433B_MOUSE
# 3  1433B_MOUSE
# 4  1433B_MOUSE

# %%
path= 'C:/Users/hmdebern.UTMB-USERS-M/Desktop/may2testwithioscorezero'
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)

# %%
datazionscore=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    datazionscore=pd.concat([datazionscore,d])
# datazionscore=datazionscore[datazionscore.NDP >=4]
print(datazionscore.shape)
datazionscore.head()
# Out:
# (32620, 14)
#    proteinName           peptideSeq  old_Rsquared  new_Rsquared  NDP  \
# 0  1433B_MOUSE           DSTLImQLLR      0.405407      0.842207    8
# 1  1433B_MOUSE       AVTEQGHELSNEER     -0.515961     -0.132980    7
# 2  1433B_MOUSE     LAEQAERYDDMAAAMK     -0.067008      0.388974    5
# 3  1433B_MOUSE  TAFDEAIAELDTLNEESYK      0.937993      0.978693    8
# 4  1433B_MOUSE  TAFDEAIAELDTLNEESYK      0.636834      0.973459    9
#
#    rateconstant     sigma     Abundance  MassToCharge      RMSE  \
# 0       0.63353  0.500928  1.913215e+07     603.33154  0.109762
# 1       0.47244  0.510142  4.919352e+07     533.58502  0.241501
# 2       0.13982  0.087811  1.312825e+08     906.91638  0.086949
# 3       0.39895  0.039049  1.747170e+07    1080.00488  0.016933
# 4       0.27219  0.065604  2.121646e+07     720.33905  0.047914
#
#    selected_A1A0_count   selected_A2A0_count   selected_A2A1_count  \
# 0                  1.0                   3.0                   1.0
# 1                  2.0                   1.0                   4.0
# 2                  3.0                   0.0                   0.0
# 3                  3.0                   1.0                   3.0
# 4                  2.0                   1.0                   1.0
#
#        Protein
# 0  1433B_MOUSE
# 1  1433B_MOUSE
# 2  1433B_MOUSE
# 3  1433B_MOUSE
# 4  1433B_MOUSE

# %%
mergeddata=data[["proteinName","peptideSeq","MassToCharge","old_Rsquared","NDP"]].merge(datazionscore[["proteinName","peptideSeq","MassToCharge","old_Rsquared","NDP"]], 
                                                                                  on=["proteinName","peptideSeq","MassToCharge"],suffixes=["_","_zeroIonscore"])

mergeddata["NDP_Diff"]=mergeddata["NDP_"]-mergeddata["NDP_zeroIonscore"]
print(mergeddata.shape)
mergeddata.fillna(0)
mergeddata.head()
# Out:
# (32620, 8)
#    proteinName           peptideSeq  MassToCharge  old_Rsquared_  NDP_  \
# 0  1433B_MOUSE           DSTLImQLLR     603.33154       0.405407     8
# 1  1433B_MOUSE       AVTEQGHELSNEER     533.58502      -0.515961     7
# 2  1433B_MOUSE     LAEQAERYDDMAAAMK     906.91638      -0.067008     5
# 3  1433B_MOUSE  TAFDEAIAELDTLNEESYK    1080.00488       0.937993     8
# 4  1433B_MOUSE  TAFDEAIAELDTLNEESYK     720.33905       0.636834     9
#
#    old_Rsquared_zeroIonscore  NDP_zeroIonscore  NDP_Diff
# 0                   0.405407                 8         0
# 1                  -0.515961                 7         0
# 2                  -0.067008                 5         0
# 3                   0.937993                 8         0
# 4                   0.636834                 9         0

# %%
# mergeddata[(mergeddata["old_Rsquared_"]<0.9)&( mergeddata["old_Rsquared_zeroIonscore"]>=0.9)]
# mergeddata[(mergeddata["old_Rsquared_"]<0.9)&( mergeddata["old_Rsquared_zeroIonscore"]>=0.9)]
# Out:
# Empty DataFrame
# Columns: [proteinName, peptideSeq, MassToCharge, old_Rsquared_, NDP_, old_Rsquared_zeroIonscore, NDP_zeroIonscore]
# Index: []

# %%
mergeddata.
