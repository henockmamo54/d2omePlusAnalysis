# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Read UTMB data

# %%
utmb_data= pd.read_csv("compare.csv")[["Portien","rateconst"]]
utmb_list= pd.read_csv("Protein_List.utmb.0311_2022.csv")[["Entry","Entry name","Gene names"]]
utmb_data=utmb_data.merge(utmb_list,left_on=["Portien"],right_on=["Entry name"])[["Entry","Entry name",
                                                                                  "rateconst","Gene names"]]
utmb_data["Gene names"]=[(str(x).strip().split(' ')[0]).strip() for x in utmb_data["Gene names"]]
utmb_data["utmb_HL"]=[math.log(2)/x if x>0 else None for x in utmb_data["rateconst"] ]
print(utmb_data.shape)
utmb_data.head()
# Out:
# (1777, 5)
#     Entry   Entry name  rateconst Gene names   utmb_HL
# 0  Q9CQV8  1433B_MOUSE   0.331168      Ywhab  2.093038
# 1  P62259  1433E_MOUSE   0.295008      Ywhae  2.349588
# 2  P68510  1433F_MOUSE   0.453521      Ywhah  1.528368
# 3  P61982  1433G_MOUSE   0.354219      Ywhag  1.956832
# 4  P68254  1433T_MOUSE   0.435773      Ywhaq  1.590615

# %% [markdown]
# ## 2. Read mRNA half life data

# %%
mrna_data=pd.read_excel("mRNA_Half_Lives_pnas.1715225115.sd01.xlsx",sheet_name="Sheet2")[["gene",'half.life', 'cv.half.life']]
mrna_data["gene"]=[ str(x).strip() for x in mrna_data["gene"]]
# mrna_data["mRNA_k"]=[math.log(2)/x for x in mrna_data["half.life"]]
# mrna_data=mrna_data.dropna()
print(mrna_data.shape)
mrna_data.head()
# Out:
# (12216, 3)
#     gene  half.life  cv.half.life
# 0  Gnai3        NaN           NaN
# 1  Cdc45   0.166667      5.277888
# 2   Apoh   9.192603      0.738041
# 3   Narf   1.446211      0.159744
# 4   Cav2        NaN           NaN

# %% [markdown]
# ## 3. Merge mrna & utmb data

# %%
data=mrna_data.merge(utmb_data, left_on='gene', right_on='Gene names',how='right')
data=data[['gene', 'Entry', 'Entry name', 'Gene names', 'utmb_HL','half.life', 'cv.half.life', 'rateconst']]
print(data.shape)
data.head()
# Out:
# (1777, 8)
#     gene   Entry   Entry name Gene names   utmb_HL  half.life  cv.half.life  \
# 0  Ywhab  Q9CQV8  1433B_MOUSE      Ywhab  2.093038        NaN           NaN
# 1  Ywhae  P62259  1433E_MOUSE      Ywhae  2.349588        NaN           NaN
# 2  Ywhah  P68510  1433F_MOUSE      Ywhah  1.528368   0.166667      2.774646
# 3  Ywhag  P61982  1433G_MOUSE      Ywhag  1.956832   0.166667      2.590179
# 4  Ywhaq  P68254  1433T_MOUSE      Ywhaq  1.590615        NaN           NaN
#
#    rateconst
# 0   0.331168
# 1   0.295008
# 2   0.453521
# 3   0.354219
# 4   0.435773

# %%
data.sort_values(by=['gene'])
data[pd.isna(data["gene"])]
# Out:
#      gene   Entry   Entry name Gene names   utmb_HL  half.life  cv.half.life  \
# 9     NaN  Q61767  3BHS4_MOUSE     Hsd3b4  5.169384        NaN           NaN
# 39    NaN  Q8K4F5  ABHDB_MOUSE     Abhd11  4.829015        NaN           NaN
# 73    NaN  Q8BFZ3  ACTBL_MOUSE     Actbl2  3.355394        NaN           NaN
# 75    NaN  P68033   ACTC_MOUSE      Actc1  2.238508        NaN           NaN
# 76    NaN  P63260   ACTG_MOUSE      Actg1  3.604566        NaN           NaN
# ...   ...     ...          ...        ...       ...        ...           ...
# 1697  NaN  Q921I1   TRFE_MOUSE         Tf  0.633627        NaN           NaN
# 1729  NaN  Q64435   UD16_MOUSE     Ugt1a6  2.484639        NaN           NaN
# 1734  NaN  P17717  UDB17_MOUSE    Ugt2b17  1.665154        NaN           NaN
# 1735  NaN  P70362   UFD1_MOUSE       Ufd1  1.291710        NaN           NaN
# 1742  NaN  Q283N4   URAD_MOUSE       Urad  1.109632        NaN           NaN
#
#       rateconst
# 9      0.134087
# 39     0.143538
# 73     0.206577
# 75     0.309647
# 76     0.192297
# ...         ...
# 1697   1.093936
# 1729   0.278973
# 1734   0.416266
# 1735   0.536612
# 1742   0.624664
#
# [204 rows x 8 columns]

# %%
data[data['utmb_HL']>500]
# Out:
#        gene   Entry   Entry name Gene names     utmb_HL  half.life  \
# 1096  Nubpl  Q9CWD8  NUBPL_MOUSE      Nubpl  2139.34315  10.426948
#
#       cv.half.life  rateconst
# 1096      0.530303   0.000324

# %% [markdown]
# ## 4. clean up

# %%
plt.scatter(data["half.life"], data["utmb_HL"])
plt.xlabel("mRNA")
plt.ylabel("UTMB")
# Out:
# Text(0, 0.5, 'UTMB')

# %%
data=data.dropna()
data=data[data["half.life"]!=0.166666666666667 ]
data=data[data["cv.half.life"]<2]
data=data[data["utmb_HL"]<500]
data=data.sort_values(by=["utmb_HL"])
data.head(15)
# Out:
#          gene   Entry   Entry name Gene names   utmb_HL  half.life  \
# 1617     Tdo2  P48776   T23O_MOUSE       Tdo2  0.078371   2.629887
# 159      Apoe  P08226   APOE_MOUSE       Apoe  0.090605   0.736282
# 593     Fads2  Q9Z0R9  FADS2_MOUSE      Fads2  0.112829   1.566399
# 312        C3  P01027    CO3_MOUSE         C3  0.120361  15.320379
# 1007    Mup20  Q5FW60  MUP20_MOUSE      Mup20  0.126141   1.984450
# 740     H2-D1  P01899   HA11_MOUSE      H2-D1  0.138339   0.848745
# 6     Ppp2r5e  Q61151   2A5E_MOUSE    Ppp2r5e  0.138387   2.298928
# 791       Hrg  Q9ESB3    HRG_MOUSE        Hrg  0.147162   3.417963
# 1149     Pck1  Q9Z2V4  PCKGC_MOUSE       Pck1  0.148217   0.624216
# 819      Idi1  P58044   IDI1_MOUSE       Idi1  0.149718   8.354478
# 314       C4b  P01029   CO4B_MOUSE        C4b  0.156685   7.138104
# 301      Clpx  Q9JHS4   CLPX_MOUSE       Clpx  0.162100   0.194093
# 318       C8g  Q8VCG4   CO8G_MOUSE        C8g  0.171479   2.484690
# 158      Apob  E9Q414   APOB_MOUSE       Apob  0.208907   2.744872
# 741     H2-K1  P01901   HA1B_MOUSE      H2-K1  0.210860   4.493101
#
#       cv.half.life  rateconst
# 1617      0.386123   8.844433
# 159       1.733502   7.650225
# 593       0.292128   6.143326
# 312       0.194065   5.758907
# 1007      0.242061   5.495015
# 740       0.778327   5.010494
# 6         0.275243   5.008772
# 791       0.411979   4.710094
# 1149      0.781566   4.676580
# 819       0.284789   4.629695
# 314       0.491928   4.423826
# 301       1.123749   4.276052
# 318       0.326364   4.042166
# 158       0.970177   3.317977
# 741       0.675279   3.287232

# %%
plt.scatter(data["half.life"], data["utmb_HL"])
plt.xlabel("mRNA")
plt.ylabel("UTMB")
# Out:
# Text(0, 0.5, 'UTMB')

# %%
data[["half.life","utmb_HL"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'half.life'}>,
#         <AxesSubplot:title={'center':'utmb_HL'}>]], dtype=object)
