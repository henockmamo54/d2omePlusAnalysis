# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
utmb_data= pd.read_csv("compare.csv")[["Portien","rateconst","PeptideCount"]]
utmb_list= pd.read_csv("Protein_List.utmb.0311_2022.csv")[["Entry","Entry name","Gene names"]]
utmb_data=utmb_data.merge(utmb_list,left_on=["Portien"],right_on=["Entry name"])[["Entry","Entry name",
                                                                                  "rateconst","Gene names","PeptideCount"]]
print(utmb_data.shape)
utmb_data.head()
# Out:
# (1773, 5)
#     Entry   Entry name  rateconst Gene names  PeptideCount
# 0  Q9CQV8  1433B_MOUSE   0.297362      Ywhab             8
# 1  P62259  1433E_MOUSE   0.301345      Ywhae            18
# 2  P68510  1433F_MOUSE   0.395838      Ywhah             4
# 3  P61982  1433G_MOUSE   0.373152      Ywhag             7
# 4  P68254  1433T_MOUSE   0.557099      Ywhaq            10

# %%
Liver15N2H_GVB_Mouse=pd.read_csv("Liver.Proteins.Turnover.15N.and.2H.GVB_Mouse.csv",skiprows=1)[["Uniprot Gene Name","k0",'# Total Peptides']]
print(Liver15N2H_GVB_Mouse.shape)
Liver15N2H_GVB_Mouse.head()
# Out:
# (1329, 3)
#   Uniprot Gene Name        k0  # Total Peptides
# 0       LPP60_MOUSE  0.805279                 2
# 1        FGGY_MOUSE  0.126051                 4
# 2        SPEB_MOUSE  0.123579                 6
# 3       DHTK1_MOUSE  0.141873                40
# 4        TOM5_MOUSE  0.129240                 1

# %%
utmb_Liver15N2H_GVB_Mouse=Liver15N2H_GVB_Mouse.merge(utmb_data,left_on=["Uniprot Gene Name"],right_on=["Entry name"])
print(utmb_Liver15N2H_GVB_Mouse.shape)
utmb_Liver15N2H_GVB_Mouse.head()
# Out:
# (1098, 8)
#   Uniprot Gene Name        k0  # Total Peptides   Entry   Entry name  \
# 0       LPP60_MOUSE  0.805279                 2  A0JNU3  LPP60_MOUSE
# 1        FGGY_MOUSE  0.126051                 4  A2AJL3   FGGY_MOUSE
# 2        SPEB_MOUSE  0.123579                 6  A2AS89   SPEB_MOUSE
# 3       DHTK1_MOUSE  0.141873                40  A2ATU0  DHTK1_MOUSE
# 4       SC22B_MOUSE  0.202260                 9  O08547  SC22B_MOUSE
#
#    rateconst       Gene names  PeptideCount
# 0   0.732540             Aspg            10
# 1   0.291233             Fggy            11
# 2   0.101904            Agmat            14
# 3   0.252823  Dhtkd1 Kiaa1630            11
# 4   0.294941   Sec22b Sec22l1             5

# %%
# corr= utmb_Liver15N2H_GVB_Mouse[['k0','rateconst']].corr()
# corr

# %% [markdown]
# ## 1. No Filter

# %%
plt.scatter(utmb_Liver15N2H_GVB_Mouse.k0,utmb_Liver15N2H_GVB_Mouse.rateconst,c='g')
plt.xlabel("Liver15N2H_GVB_Mouse")
plt.plot(utmb_Liver15N2H_GVB_Mouse.rateconst,utmb_Liver15N2H_GVB_Mouse.rateconst,c='r')
plt.ylabel("UTMB")
# Out:
# Text(0, 0.5, 'UTMB')

# %%
temp= utmb_Liver15N2H_GVB_Mouse[(utmb_Liver15N2H_GVB_Mouse.k0<=0.7)&(utmb_Liver15N2H_GVB_Mouse.k0>0) & 
                                (utmb_Liver15N2H_GVB_Mouse.rateconst<=0.7)&(utmb_Liver15N2H_GVB_Mouse.rateconst>0)]
print(temp.shape)
plt.scatter(temp.k0,temp.rateconst,c='g')
plt.plot(temp.rateconst,temp.rateconst,c='r')
plt.xlabel("Liver15N2H_GVB_Mouse")
plt.ylabel("UTMB")
# Out:
# (818, 8)
# Text(0, 0.5, 'UTMB')

# %%
corr= temp[['k0','rateconst']].corr()
corr
# Out:
#                  k0  rateconst
# k0         1.000000   0.657223
# rateconst  0.657223   1.000000

# %% [markdown]
# ## 2. Total No. Peptides > 3

# %%
temp=utmb_Liver15N2H_GVB_Mouse[ (utmb_Liver15N2H_GVB_Mouse['# Total Peptides']>=3) 
                               & (utmb_Liver15N2H_GVB_Mouse.PeptideCount>=3)]
print(temp.shape)
# temp= utmb_Liver15N2H_GVB_Mouse[(utmb_Liver15N2H_GVB_Mouse.k0<1.5)&(utmb_Liver15N2H_GVB_Mouse.k0>0) & 
#                                 (utmb_Liver15N2H_GVB_Mouse.rateconst<1.5)&(utmb_Liver15N2H_GVB_Mouse.rateconst>0)]
plt.scatter(temp.k0,temp.rateconst,c='g') 
plt.plot(temp.rateconst,temp.rateconst,c='r')
plt.xlabel("Liver15N2H_GVB_Mouse")
plt.ylabel("UTMB")
# Out:
# (857, 8)
# Text(0, 0.5, 'UTMB')

# %%
corr= temp[['k0','rateconst']].corr()
corr
# Out:
#                 k0  rateconst
# k0         1.00000    0.39068
# rateconst  0.39068    1.00000

# %%
temp=utmb_Liver15N2H_GVB_Mouse[(utmb_Liver15N2H_GVB_Mouse['# Total Peptides']>=3)
                               & (utmb_Liver15N2H_GVB_Mouse.PeptideCount>=3)]

temp= temp[(temp.k0<=0.7)&(temp.k0>0) & 
                                (temp.rateconst<=0.7)&(temp.rateconst>0)]
print(temp.shape)
plt.scatter(temp.k0,temp.rateconst,c='b')
plt.plot(temp.rateconst,temp.rateconst,c='r')
plt.xlabel("Liver15N2H_GVB_Mouse")
plt.ylabel("UTMB")
f = plt.figure()
f.set_figwidth(9)
f.set_figheight(7)
corr= temp[['k0','rateconst']].corr()
print("corr",corr['k0']['rateconst'])
# Out:
# (706, 8)
# corr 0.7133904386983855

# %%
temp=utmb_Liver15N2H_GVB_Mouse[(utmb_Liver15N2H_GVB_Mouse['# Total Peptides']>=4)
                               & (utmb_Liver15N2H_GVB_Mouse.PeptideCount>=4)]

temp= temp[(temp.k0<=0.7)&(temp.k0>0) & 
                                (temp.rateconst<=0.7)&(temp.rateconst>0)]
print(temp.shape)
plt.scatter(temp.k0,temp.rateconst,c='b')
plt.plot(temp.rateconst,temp.rateconst,c='r')
plt.xlabel("Liver15N2H_GVB_Mouse")
plt.ylabel("UTMB")
f = plt.figure()
f.set_figwidth(9)
f.set_figheight(7)
corr= temp[['k0','rateconst']].corr()
print("corr",corr['k0']['rateconst'])
# Out:
# (633, 8)
# corr 0.7411311084330438

# %% [markdown]
# ## 3. List of Nan values

# %%
utmb_Liver15N2H_GVB_Mouse=Liver15N2H_GVB_Mouse.merge(utmb_data,left_on=["Uniprot Gene Name"],
                                                     right_on=["Entry name"],how='right')
print(utmb_Liver15N2H_GVB_Mouse.shape)
utmb_Liver15N2H_GVB_Mouse.head()
# Out:
# (1773, 8)
#   Uniprot Gene Name        k0  # Total Peptides   Entry   Entry name  \
# 0       1433B_MOUSE  0.885953               8.0  Q9CQV8  1433B_MOUSE
# 1       1433E_MOUSE  0.312108              11.0  P62259  1433E_MOUSE
# 2       1433F_MOUSE  0.141443               6.0  P68510  1433F_MOUSE
# 3       1433G_MOUSE  0.134781               6.0  P61982  1433G_MOUSE
# 4       1433T_MOUSE  0.000000               7.0  P68254  1433T_MOUSE
#
#    rateconst Gene names  PeptideCount
# 0   0.297362      Ywhab             8
# 1   0.301345      Ywhae            18
# 2   0.395838      Ywhah             4
# 3   0.373152      Ywhag             7
# 4   0.557099      Ywhaq            10

# %%
nans=utmb_Liver15N2H_GVB_Mouse[ pd.isna(utmb_Liver15N2H_GVB_Mouse.k0)]
print(nans.shape)
nans.head(50)
# Out:
# (675, 8)
#     Uniprot Gene Name  k0  # Total Peptides   Entry   Entry name  rateconst  \
# 6                 NaN NaN               NaN  Q61151   2A5E_MOUSE   0.699308
# 8                 NaN NaN               NaN  P26150  3BHS3_MOUSE   0.525015
# 9                 NaN NaN               NaN  Q61767  3BHS4_MOUSE   0.128268
# 11                NaN NaN               NaN  Q9EQC1  3BHS7_MOUSE   0.496400
# 17                NaN NaN               NaN  P07758  A1AT1_MOUSE   1.423138
# 20                NaN NaN               NaN  Q00898  A1AT5_MOUSE   1.723492
# 25                NaN NaN               NaN  Q9R078  AAKB1_MOUSE   0.155725
# 26                NaN NaN               NaN  O54950  AAKG1_MOUSE   3.689535
# 31                NaN NaN               NaN  Q61102  ABCB7_MOUSE   0.126307
# 34                NaN NaN               NaN  P61222  ABCE1_MOUSE   0.390784
# 35                NaN NaN               NaN  Q6P542  ABCF1_MOUSE   0.425634
# 36                NaN NaN               NaN  Q99LE6  ABCF2_MOUSE   0.727442
# 37                NaN NaN               NaN  Q7TMS5  ABCG2_MOUSE   0.000120
# 38                NaN NaN               NaN  Q8R2Y0  ABHD6_MOUSE   0.400289
# 42                NaN NaN               NaN  E9Q4Z2  ACACB_MOUSE   0.522499
# 51                NaN NaN               NaN  Q8K370  ACD10_MOUSE   0.146581
# 55                NaN NaN               NaN  A2AKK5  ACNT1_MOUSE   0.195093
# 56                NaN NaN               NaN  Q9DBK0  ACO12_MOUSE   0.502469
# 59                NaN NaN               NaN  O55137  ACOT1_MOUSE   0.166794
# 60                NaN NaN               NaN  Q8BWN8  ACOT4_MOUSE   0.248480
# 65                NaN NaN               NaN  Q3URE1  ACSF3_MOUSE   0.312602
# 67                NaN NaN               NaN  Q9QUJ7  ACSL4_MOUSE   5.470195
# 70                NaN NaN               NaN  Q3UNX5  ACSM3_MOUSE   0.144699
# 73                NaN NaN               NaN  Q8BFZ3  ACTBL_MOUSE   0.202227
# 75                NaN NaN               NaN  P68033   ACTC_MOUSE   0.154487
# 78                NaN NaN               NaN  Q8R5C5   ACTY_MOUSE   0.178592
# 85                NaN NaN               NaN  Q8VDL4  ADPGK_MOUSE   0.498998
# 86                NaN NaN               NaN  Q61578   ADRO_MOUSE   0.002305
# 87                NaN NaN               NaN  P48962   ADT1_MOUSE   0.175259
# 89                NaN NaN               NaN  Q9QZQ1   AFAD_MOUSE   0.277234
# 90                NaN NaN               NaN  Q8JZQ2  AFG32_MOUSE   0.129341
# 91                NaN NaN               NaN  Q9CYR6   AGM1_MOUSE   0.256489
# 93                NaN NaN               NaN  Q8BK64  AHSA1_MOUSE   0.458350
# 95                NaN NaN               NaN  P31230  AIMP1_MOUSE   0.017450
# 96                NaN NaN               NaN  Q8R010  AIMP2_MOUSE   0.106345
# 101               NaN NaN               NaN  Q9DCT1  AKCL2_MOUSE   0.225124
# 117               NaN NaN               NaN  P05063  ALDOC_MOUSE   0.204704
# 119               NaN NaN               NaN  Q9DBE8   ALG2_MOUSE   0.335332
# 120               NaN NaN               NaN  P56213    ALR_MOUSE   0.150521
# 122               NaN NaN               NaN  Q07456   AMBP_MOUSE   1.453767
# 123               NaN NaN               NaN  Q8VCT3   AMPB_MOUSE   0.252870
# 124               NaN NaN               NaN  P16406   AMPE_MOUSE   0.597155
# 127               NaN NaN               NaN  P55302   AMRP_MOUSE   0.606981
# 130               NaN NaN               NaN  Q810B6  ANFY1_MOUSE   0.173835
# 131               NaN NaN               NaN  Q9JIF0   ANM1_MOUSE   0.146701
# 137               NaN NaN               NaN  Q07076  ANXA7_MOUSE   0.497448
# 138               NaN NaN               NaN  Q64133   AOFA_MOUSE   0.208995
# 141               NaN NaN               NaN  G3X982   AOXC_MOUSE   0.452146
# 144               NaN NaN               NaN  P35585  AP1M1_MOUSE   0.260973
# 148               NaN NaN               NaN  P84091  AP2M1_MOUSE   0.238437
#
#                  Gene names  PeptideCount
# 6          Ppp2r5e Kiaa4006             1
# 8                    Hsd3b3             8
# 9                    Hsd3b4             6
# 11                   Hsd3b7             7
# 17    Serpina1a Dom1 Spi1-1            12
# 20    Serpina1e Dom5 Spi1-5             6
# 25                   Prkab1             1
# 26            Prkag1 Prkaac             3
# 31               Abcb7 Abc7             6
# 34                Abce1 Rli             9
# 35                    Abcf1             2
# 36                    Abcf2             2
# 37         Abcg2 Abcp Bcrp1             5
# 38                    Abhd6             6
# 42          Acacb Acc2 Accb            10
# 51                   Acad10            13
# 55                   Acnat1             3
# 56        Acot12 Cach Cach1             8
# 59               Acot1 Cte1            11
# 60        Acot4 Pte1b Pte2b             4
# 65                    Acsf3             7
# 67         Acsl4 Acs4 Facl4             2
# 70             Acsm3 Sa Sah            10
# 73                   Actbl2             9
# 75               Actc1 Actc             8
# 78                   Actr1b             7
# 85                    Adpgk             3
# 86                     Fdxr             5
# 87   Slc25a4 Aac1 Anc1 Ant1             8
# 89           Afdn Af6 Mllt4             4
# 90                   Afg3l2             4
# 91          Pgm3 Agm1 Pgm-3             3
# 93                    Ahsa1             4
# 95        Aimp1 Emap2 Scye1             6
# 96               Aimp2 Jtv1             8
# 101   Akr1e2 Akr1cl2 Akr1e1             5
# 117       Aldoc Aldo3 Scrg2             3
# 119          Alg2 MNCb-5081             3
# 120      Gfer Alr MNCb-0663             5
# 122               Ambp Itil             3
# 123                   Rnpep            10
# 124                   Enpep             7
# 127                  Lrpap1             6
# 130  Ankfy1 Ankhzn Kiaa1255             3
# 131     Prmt1 Hrmt1l2 Mrmt1             2
# 137              Anxa7 Anx7             6
# 138                    Maoa             7
# 141               Aox3 Aoh1            50
# 144             Ap1m1 Cltnm             6
# 148            Ap2m1 Clapm1             9
