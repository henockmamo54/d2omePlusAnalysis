# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Analyzed_Proteins_and_Their_Rates.csv")
data.head()
# Out:
#       Proteins   RateConstant   Number of peptides        SD     Abundance
# 0  1433B_MOUSE       0.302335                    6  0.047544  6.124517e+10
# 1  1433E_MOUSE       0.291690                   11  0.052363  1.518243e+11
# 2  1433F_MOUSE       0.426722                    3  0.109056  1.096620e+10
# 3  1433G_MOUSE       0.360757                    4  0.042970  4.432351e+10
# 4  1433T_MOUSE       0.602352                    5  0.208469  3.652847e+10

# %%
data=pd.read_csv("Complexes_0413_2022.csv")
data=data.replace("None",np.nan)
data=data[data[ "subunits(UniProt IDs)"]!=np.nan]
data=data[[len(x.split(';'))>=5 for x in data[ "subunits(UniProt IDs)"] ]]
data=data.reset_index(drop=True)

# %%
# utmb_data= pd.read_csv("compare.csv")[["Portien","rateconst"]]
utmb_data= pd.read_csv("Analyzed_Proteins_and_Their_Rates.csv")[["Portien","rateconst"]]

utmb_list= pd.read_csv("Protein_List.utmb.0311_2022.csv")[["Entry","Entry name","Gene names"]]
utmb_data=utmb_data.merge(utmb_list,left_on=["Portien"],right_on=["Entry name"])[["Entry","Entry name",
                                                                                  "rateconst","Gene names"]]
utmb_data=utmb_data.reset_index(drop=True)

# %%
#search
found_list={}

for i in range(utmb_data.shape[0]): 
    
    for j in range(data.shape[0]):
        
        temp=(data[ "subunits(UniProt IDs)"][j]).split(';')
        temp=[x.strip() for x in temp]
        
        if((utmb_data["Entry"][i]).strip() in temp):
            
            if( (data["ComplexID"][j]) in found_list.keys()):
                
                found_list[data["ComplexID"][j]]["protiens"].append(utmb_data["Entry"][i])
                found_list[data["ComplexID"][j]]["protiens_name"].append(utmb_data["Entry name"][i])
                found_list[data["ComplexID"][j]]["k"].append(float(utmb_data["rateconst"][i]))
                
            else:
                found_list[(data["ComplexID"][j])]={"name":data["ComplexName"][j],
                                                  "protiens":[utmb_data["Entry"][i]],
                                                  "protiens_name":[utmb_data["Entry name"][i]],
                                                  "k":[ float(utmb_data["rateconst"][i])]}
#             found_list.append([data["ComplexName"][j],data["ComplexID"][j],utmb_data["Entry"][i],utmb_data["rateconst"][i]
#                                ])

# %%
len(found_list.keys())
# Out:
# 53

# %%
Filtered_vals = dict()
for new_ke, new_val in found_list.items():
    
    if len(new_val["protiens"])>=5:
        Filtered_vals[new_ke] = new_val

# %%
df=pd.DataFrame(Filtered_vals)
df=df.transpose()
df=df.reset_index()
df.head(20)
# Out:
#     index                                               name  \
# 0    3146                              Coatomer-Arf1 complex
# 1     413  (ER)-localized multiprotein complex, Ig heavy ...
# 2     414  (ER)-localized multiprotein complex, in absenc...
# 3    3145                                   Coatomer complex
# 4     538                Cytochrome c oxidase, mitochondrial
# 5      40  COP9 signalosome complex (Gps1, Cops1, Cops2, ...
# 6     495              Cytochrome bc1-complex, mitochondrial
# 7    3029                                     Drosha complex
# 8    3047               Parvulin-associated pre-rRNP complex
# 9     381         Respiratory chain complex I, mitochondrial
# 10    382         Respiratory chain complex I, mitochondrial
# 11     38                                     20S proteasome
# 12     39                                   Immunoproteasome
# 13     51   CCT complex (chaperonin containing TCP1 complex)
# 14     52   CCT complex (chaperonin containing TCP1 complex)
# 15    132   CCT complex (chaperonin containing TCP1 complex)
# 16   3072  CCT complex (chaperonin containing TCP1 comple...
#
#                                              protiens  \
# 0   [P84078, Q8CIE6, O55029, Q9JIF7, Q5XJY5, O8907...
# 1   [P20029, Q99KV1, P08113, Q9JKR6, P09103, P0800...
# 2   [P20029, P08113, Q9JKR6, P09103, P08003, P2436...
# 3    [Q8CIE6, O55029, Q9JIF7, Q5XJY5, O89079, Q9QZE5]
# 4   [P00405, P19783, P12787, P19536, Q9CPQ1, P4302...
# 5    [P61202, O88543, O88544, O35864, O88545, Q8VBV7]
# 6   [Q9D0M3, Q9CZ13, Q9DB77, Q9D855, Q9CQ69, Q8R1I...
# 7    [Q501J6, Q61656, O35286, O35737, Q9D0E1, Q921F2]
# 8   [Q9JIK5, Q61656, Q9D8N0, P35550, P11276, Q7TPV...
# 9   [Q9CQ75, Q62425, Q9CPP6, Q9CQZ5, Q9DCJ5, Q9DC6...
# 10  [Q9CQ75, Q62425, Q9CPP6, Q9CQZ5, Q9DCJ5, Q9DC6...
# 11  [Q9R1P4, P49722, O70435, Q9R1P0, Q9Z2U1, Q9QUM...
# 12  [Q9R1P4, P49722, O70435, Q9R1P0, Q9Z2U1, Q9QUM...
# 13  [P11983, P80314, P80315, P80316, P80318, P8031...
# 14  [P11983, P80314, P80315, P80316, P80318, P8031...
# 15  [P11983, P80314, P80315, P80316, P80318, P8031...
# 16  [P11983, P80314, P80315, P80316, P80318, P8031...
#
#                                         protiens_name  \
# 0   [ARF1_MOUSE, COPA_MOUSE, COPB2_MOUSE, COPB_MOU...
# 1   [BIP_MOUSE, DJB11_MOUSE, ENPL_MOUSE, HYOU1_MOU...
# 2   [BIP_MOUSE, ENPL_MOUSE, HYOU1_MOUSE, PDIA1_MOU...
# 3   [COPA_MOUSE, COPB2_MOUSE, COPB_MOUSE, COPD_MOU...
# 4   [COX2_MOUSE, COX41_MOUSE, COX5A_MOUSE, COX5B_M...
# 5   [CSN2_MOUSE, CSN3_MOUSE, CSN4_MOUSE, CSN5_MOUS...
# 6   [CY1_MOUSE, QCR1_MOUSE, QCR2_MOUSE, QCR7_MOUSE...
# 7   [DDX17_MOUSE, DDX5_MOUSE, DHX15_MOUSE, HNRH1_M...
# 8   [DDX21_MOUSE, DDX5_MOUSE, EF1G_MOUSE, FBRL_MOU...
# 9   [NDUA2_MOUSE, NDUA4_MOUSE, NDUA5_MOUSE, NDUA6_...
# 10  [NDUA2_MOUSE, NDUA4_MOUSE, NDUA5_MOUSE, NDUA6_...
# 11  [PSA1_MOUSE, PSA2_MOUSE, PSA3_MOUSE, PSA4_MOUS...
# 12  [PSA1_MOUSE, PSA2_MOUSE, PSA3_MOUSE, PSA4_MOUS...
# 13  [TCPA_MOUSE, TCPB_MOUSE, TCPD_MOUSE, TCPE_MOUS...
# 14  [TCPA_MOUSE, TCPB_MOUSE, TCPD_MOUSE, TCPE_MOUS...
# 15  [TCPA_MOUSE, TCPB_MOUSE, TCPD_MOUSE, TCPE_MOUS...
# 16  [TCPA_MOUSE, TCPB_MOUSE, TCPD_MOUSE, TCPE_MOUS...
#
#                                                     k
# 0   [0.528111, 0.419825, 0.11471, 0.438532, 0.4108...
# 1   [0.43746, 0.322184, 0.375641, 0.414183, 0.4230...
# 2   [0.43746, 0.375641, 0.414183, 0.423001, 0.4343...
# 3   [0.419825, 0.11471, 0.438532, 0.410846, 0.2860...
# 4   [0.074373, 0.143172, 0.250622, 0.118104, 0.163...
# 5   [0.0, 0.251251, 0.298108, 0.560267, 0.228769, ...
# 6   [0.112568, 0.101595, 0.16756, 0.253361, 0.1475...
# 7   [1.327065, 1.725335, 0.415308, 0.371442, 0.274...
# 8   [0.52597, 1.725335, 0.104508, 0.212225, 0.8568...
# 9   [0.083147, 0.557361, 0.163865, 0.324781, 0.125...
# 10  [0.083147, 0.557361, 0.163865, 0.324781, 0.125...
# 11  [0.272875, 0.313, 0.303015, 0.258161, 0.275601...
# 12  [0.272875, 0.313, 0.303015, 0.258161, 0.275601...
# 13  [0.410336, 0.256684, 0.318105, 0.30856, 0.4105...
# 14  [0.410336, 0.256684, 0.318105, 0.30856, 0.4105...
# 15  [0.410336, 0.256684, 0.318105, 0.30856, 0.4105...
# 16  [0.410336, 0.256684, 0.318105, 0.30856, 0.4105...

# %%
# df["k_sd"]=0
# df["k_median"]=0
# df["k_mean_val"]=0

# for i in range(df.shape[0]):
#     temp= np.array( df.k[i]) 
    
#     df.k_mean_val[i]= np.mean(temp)
#     df.k_median[i]= np.median(temp )
#     df.k_sd[i]= np.std( temp)
    
# df[["name","k","k_sd","k_median","protiens_name","protiens"]]

# %%
complex_name=[]
complex_data=[]

for i in range(df.shape[0]):
    if(df.name[i] not in complex_name):
        complex_name.append(df.name[i])
        complex_data.append(df.k[i])

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([1, 1, 1, 1])

# Creating plot
bp = ax.boxplot(complex_data,vert =False)
plt.yticks(range(1,len(complex_name)+1), complex_name) 
 
# show plot
plt.show()

# %%
compd=pd.DataFrame()

for i in range(df.shape[0]):
    
    perc= pd.DataFrame()
    perc["k"]=df['k'][i]
    perc["name"]=df['name'][i]
    compd=pd.concat([compd,perc])

# %%
# fig = plt.gcf()
fig, ax = plt.subplots(1)

# Change seaborn plot size
fig.set_size_inches(10, 8)

sns.boxplot(x="k", y="name", data=compd,orient ='h')
# sns.swarmplot(x="k", y="name", data=compd,orient='h', color=".25")
plt.xlabel('')
plt.ylabel('')
# sns.swarmplot(x="name", y="k", data=compd, color=".25")
# Out:
# Text(0, 0.5, '')

# %%
import textwrap
# fig = plt.gcf()

fig, ax = plt.subplots(1)

# Change seaborn plot size
fig.set_size_inches(12, 12)
# sns.set(font_scale = 1)
sns.boxplot(x="k", y="name", data=compd,orient ='h')
sns.swarmplot(x="k", y="name", data=compd,orient='h', color=".25")
plt.xlabel('')
plt.ylabel('')
plt.legend([],[], frameon=False)
# sns.swarmplot(x="name", y="k", data=compd, color=".25")

# plt.xlabel('', fontsize=16);
# plt.ylabel('', fontsize=16);
# plt.title(' Data', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=12)
ax.set_yticklabels([textwrap.fill(e, 40) for e in complex_name])
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# C:\Workplace\Python\d2omeplusAnalysis\d2omePlusAnalysis

# %%
# x=list(df[df.name=='Drosha complex']['protiens_name'])
# x

# %%
# x=list(df[df.name=='Drosha complex']['k'])
# x
