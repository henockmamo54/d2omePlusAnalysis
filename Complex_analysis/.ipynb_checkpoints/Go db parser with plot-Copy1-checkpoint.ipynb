# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
#  do not forget to format the header
# <?xml version="1.0" encoding="UTF-8"?>
# <overrepresentation>
# <result>
#         <term>
#             <id>GO:0036125</id>
#             <label>fatty acid beta-oxidation multienzyme complex</label>
#         </term>
#         <number_in_reference>2</number_in_reference>
#         <input_list>
#             <list_name>upload_1</list_name>
#             <number_in_list>2</number_in_list>
#             <expected>0.16229485838978042</expected>
#             <plus_minus>+</plus_minus>
#             <pValue>0.030501094409911566</pValue>
#             <fold_enrichment>12.323249299719889</fold_enrichment>
#             <fdr>0.15874610517690546</fdr>
#             <mapped_id_list>
#                 <mapped_id>Q99JY0</mapped_id>
#                 <mapped_id>Q8BMS1</mapped_id>
#             </mapped_id_list>
#         </input_list>
#     </result>

# %% [markdown]
# # Parse GO DB data

# %%
import pandas as pd
import xml.etree.ElementTree as ET

def iter_records(records):
    temp_dict = []   
    for record in records:
        # temporary dictionary to hold values        
        
        print("====================================")
        print("====================================")
        try:
            print((record[0][1].text)) # complex name 
        except:
             print((record[0][0].text))
            
        print(record[1].text)                       # protien count 
        print(record[2][2].text)                    # expected        
        print(record[2][4].text)                    # pValue        
        print(record[2][5].text)                    # fold_enrichment        
        print(record[2][6].text)                    # fdr
        
        
        proteinlist=[]
        
        try:
            for i in record[2][7]:
                print(i.text)
                proteinlist.append(i.text) 
        except:
            print("Error Reading proeint list")
        
        
        try:
            temp_dict.append([record[0][1].text, int(record[1].text),record[2][2].text,record[2][4].text,
                          float(record[2][5].text),float(record[2][6].text),proteinlist]   )
        except:
             temp_dict.append([record[0][0].text,int(record[1].text),record[2][2].text,record[2][4].text,
                          float(record[2][5].text),float(record[2][6].text),proteinlist]   )
                
                
        
        print("====================================")
        print("====================================")
    return temp_dict
 
        
def read_xml(xmlFileName):
    with open(xmlFileName, 'r') as xml_file:
        # read the data and store it as a tree
        tree = ET.parse(xml_file)

        # get the root of the tree
        root = tree.getroot()
         
        # return the DataFrame
        return pd.DataFrame(list(iter_records(root)))

# %%
parsedData=read_xml("C:/Workplace/Python/d2omeplusAnalysis/d2omePlusAnalysis/GO_Database_UTMB_mouse_liver/analysis - Copy.xml")
# Out:
# ====================================
# ====================================
# fatty acid beta-oxidation multienzyme complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15874610517690546
# Q99JY0
# Q8BMS1
# ====================================
# ====================================
# ====================================
# ====================================
# gamma-catenin-TCF7L2 complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4916768687950538
# Q02257
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial proton-transporting ATP synthase, stator stalk
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15834114062288274
# Q9DCX2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# late endosome lumen
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15793823695717565
# P16858
# P63017
# ====================================
# ====================================
# ====================================
# ====================================
# ectoplasm
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4908560392979001
# Q8VCB3
# ====================================
# ====================================
# ====================================
# ====================================
# UBC13-UEV1A complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15753737848774121
# Q9CZY3
# P61089
# ====================================
# ====================================
# ====================================
# ====================================
# intracellular ferritin complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.49003794589907024
# P29391
# ====================================
# ====================================
# ====================================
# ====================================
# methylcrotonoyl-CoA carboxylase complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15713854968144314
# Q99MR8
# Q3ULD5
# ====================================
# ====================================
# ====================================
# ====================================
# 6-phosphofructo-2-kinase/fructose-2,6-biphosphatase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.48922257494083554
# P70266
# ====================================
# ====================================
# ====================================
# ====================================
# growth cone leading edge
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4884099128562162
# Q9JM76
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial prohibitin complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15674173516204554
# P67778
# O35129
# ====================================
# ====================================
# ====================================
# ====================================
# ventral surface of cell
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4875999461682291
# Q9CVB6
# ====================================
# ====================================
# ====================================
# ====================================
# actin filament branch point
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.48679266148914263
# Q9CVB6
# ====================================
# ====================================
# ====================================
# ====================================
# apical ectoplasmic specialization
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15634691970823686
# O55143
# Q99JY9
# ====================================
# ====================================
# ====================================
# ====================================
# podosome ring
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4859880455197391
# Q9CVB6
# ====================================
# ====================================
# ====================================
# ====================================
# podosome core
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.047550445788071515
# P61161
# Q9CVB6
# Q99JY9
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome storage granule
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1559540882516835
# Q3TXS7
# Q8VDM4
# ====================================
# ====================================
# ====================================
# ====================================
# lysosomal matrix
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15556322587511287
# P17047
# P63017
# ====================================
# ====================================
# ====================================
# ====================================
# nucleoplasmic periphery of the nuclear pore complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1551743178104251
# Q9Z204
# P49312
# ====================================
# ====================================
# ====================================
# ====================================
# COPI-coated Golgi to ER transport vesicle
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4851860850485844
# Q6R0H7
# ====================================
# ====================================
# ====================================
# ====================================
# basal body patch
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.48438676695130506
# P63260
# ====================================
# ====================================
# ====================================
# ====================================
# calpain complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.154787349436833
# O08529
# O88456
# ====================================
# ====================================
# ====================================
# ====================================
# Sec62/Sec63 complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.483590078189872
# Q8VHE0
# ====================================
# ====================================
# ====================================
# ====================================
# endoplasmic reticulum Sec complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.48279600581189186
# Q8VHE0
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial fatty acid beta-oxidation multienzyme complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15440230627902995
# Q99JY0
# Q8BMS1
# ====================================
# ====================================
# ====================================
# ====================================
# succinate-CoA ligase complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.04739454268712702
# Q9Z2I9
# Q9Z2I8
# Q9WUM5
# ====================================
# ====================================
# ====================================
# ====================================
# nitric-oxide synthase complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.0472396585606985
# Q9DCN2
# Q9CW42
# Q9CQX2
# ====================================
# ====================================
# ====================================
# ====================================
# serine-pyruvate aminotransferase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4820045369499052
# Q8BL66
# ====================================
# ====================================
# ====================================
# ====================================
# glycine cleavage complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1540191740053847
# Q91WK5
# Q91W43
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic translation initiation factor 3 complex, eIF3m
# 8
# 0.6491794335591217
# 7.383766846789922E-6
# 12.323249299719889
# 1.147020269711259E-4
# Q99JX4
# Q91WK2
# Q9QZD9
# O70194
# Q9DCH4
# P23116
# Q8R1B4
# Q8JZQ9
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic translation initiation factor 3 complex, eIF3e
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.48121565882069095
# P23116
# ====================================
# ====================================
# ====================================
# ====================================
# acetolactate synthase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4804293587245787
# Q8BU33
# ====================================
# ====================================
# ====================================
# ====================================
# other organism part
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.47964562404476696
# P01029
# ====================================
# ====================================
# ====================================
# ====================================
# PAS complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4788644422466485
# Q80WQ2
# ====================================
# ====================================
# ====================================
# ====================================
# integral component of autophagosome membrane
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4780858008771417
# P17047
# ====================================
# ====================================
# ====================================
# ====================================
# intrinsic component of autophagosome membrane
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4773096875640295
# P17047
# ====================================
# ====================================
# ====================================
# ====================================
# translation initiation ternary complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.47653609001530334
# Q6ZWX6
# ====================================
# ====================================
# ====================================
# ====================================
# endopeptidase Clp complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15363793842616347
# Q9JHS4
# O88696
# ====================================
# ====================================
# ====================================
# ====================================
# succinate-CoA ligase complex (ADP-forming)
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4757649960185148
# Q9WUM5
# ====================================
# ====================================
# ====================================
# ====================================
# Tapasin-ERp57 complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15325858549177787
# P27773
# Q9R233
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial oxoglutarate dehydrogenase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4749963934401327
# Q9CQX8
# ====================================
# ====================================
# ====================================
# ====================================
# glycerol-3-phosphate dehydrogenase complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.04708578345138026
# Q3ULJ0
# P13707
# Q64521
# ====================================
# ====================================
# ====================================
# ====================================
# chaperone-mediated autophagy translocation complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4742302702249067
# P17047
# ====================================
# ====================================
# ====================================
# ====================================
# phenylalanine-tRNA ligase complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1528811012910592
# Q9WUA2
# Q8C0C7
# ====================================
# ====================================
# ====================================
# ====================================
# VCP-NSFL1C complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15250547204955783
# Q01853
# Q9CZ44
# ====================================
# ====================================
# ====================================
# ====================================
# myosin V complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.47346661439523696
# Q9D0M5
# ====================================
# ====================================
# ====================================
# ====================================
# presynaptic actin cytoskeleton
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4727054140505501
# P63260
# ====================================
# ====================================
# ====================================
# ====================================
# catalase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.47194665736668084
# P24270
# ====================================
# ====================================
# ====================================
# ====================================
# cargo receptor complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4711903325952599
# Q91ZX7
# ====================================
# ====================================
# ====================================
# ====================================
# low-density lipoprotein receptor complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4704364280631074
# Q91ZX7
# ====================================
# ====================================
# ====================================
# ====================================
# proton-transporting ATP synthase, catalytic core
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4696849321716328
# Q03265
# ====================================
# ====================================
# ====================================
# ====================================
# proton-transporting ATP synthase, stator stalk
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15213168412786773
# Q9DCX2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# electron transfer flavoprotein complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.046932907531083576
# Q921G7
# Q99LC5
# Q9DCW4
# ====================================
# ====================================
# ====================================
# ====================================
# succinate-CoA ligase complex (GDP-forming)
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15175972401997564
# Q9Z2I8
# Q9WUM5
# ====================================
# ====================================
# ====================================
# ====================================
# macropinocytic cup
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4689358333962395
# Q9D8U8
# ====================================
# ====================================
# ====================================
# ====================================
# glucosidase II complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.15138957835163425
# O08795
# Q8BHN3
# ====================================
# ====================================
# ====================================
# ====================================
# hexameric IgM immunoglobulin complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4681891202857359
# P01872
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic 80S initiation complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4674447814617522
# Q9JJI8
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic 48S preinitiation complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46670280561816213
# Q6ZWX6
# ====================================
# ====================================
# ====================================
# ====================================
# retromer, cargo-selective complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.046781021098944144
# Q9QZ88
# Q9EQH3
# P40336
# ====================================
# ====================================
# ====================================
# ====================================
# retromer, tubulation complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1510212338787592
# Q9CWK8
# Q9WV80
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial electron transfer flavoprotein complex
# 3
# 0.24344228758467062
# 0.007103358977677513
# 12.323249299719889
# 0.04663011457927013
# Q921G7
# Q99LC5
# Q9DCW4
# ====================================
# ====================================
# ====================================
# ====================================
# symbiont cell surface
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4659631815205105
# P01029
# ====================================
# ====================================
# ====================================
# ====================================
# translation initiation complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46522589800544645
# Q9JJI8
# ====================================
# ====================================
# ====================================
# ====================================
# mature chylomicron
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4644909439801614
# E9Q414
# ====================================
# ====================================
# ====================================
# ====================================
# septin filament array
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4637583084218331
# O55131
# ====================================
# ====================================
# ====================================
# ====================================
# glutamate-cysteine ligase complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1506546774858496
# P97494
# O09172
# ====================================
# ====================================
# ====================================
# ====================================
# U11/U12 snRNP
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46302798037707427
# Q99NB9
# ====================================
# ====================================
# ====================================
# ====================================
# aminoacyl-tRNA synthetase multienzyme complex
# 12
# 0.9737691503386825
# 3.5557104186794725E-8
# 12.323249299719889
# 8.1301918000143E-7
# Q68FL6
# Q8CGC7
# Q8BML9
# Q8BMJ2
# Q8R010
# Q9D1M4
# P47962
# P31230
# Q99MN1
# Q8BU30
# Q922B2
# Q9D0I9
# ====================================
# ====================================
# ====================================
# ====================================
# UFD1-NPL4 complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.1502898961844311
# P60670
# P70362
# ====================================
# ====================================
# ====================================
# ====================================
# 4-aminobutyrate transaminase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46229994896138704
# P61922
# ====================================
# ====================================
# ====================================
# ====================================
# multi-eIF complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.14992687711152183
# P23116
# Q6ZWX6
# ====================================
# ====================================
# ====================================
# ====================================
# UBC13-MMS2 complex
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.14956560752812056
# P61089
# Q9D2M8
# ====================================
# ====================================
# ====================================
# ====================================
# actin rod
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4615742033586219
# P18760
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial endopeptidase Clp complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46085073282044225
# Q9JHS4
# ====================================
# ====================================
# ====================================
# ====================================
# extrinsic component of lysosome membrane
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.46012952666579365
# P51150
# ====================================
# ====================================
# ====================================
# ====================================
# 3-methylcrotonyl-CoA carboxylase complex, mitochondrial
# 2
# 0.16229485838978042
# 0.030501094409911566
# 12.323249299719889
# 0.14920607481771644
# Q99MR8
# Q3ULD5
# ====================================
# ====================================
# ====================================
# ====================================
# ferritin complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.45941057428037835
# P29391
# ====================================
# ====================================
# ====================================
# ====================================
# apolipoprotein B mRNA editing enzyme complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4586938651161344
# Q5YD48
# ====================================
# ====================================
# ====================================
# ====================================
# inactive sex chromosome
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.45797938869071986
# Q8VEK3
# ====================================
# ====================================
# ====================================
# ====================================
# multivesicular body, internal vesicle lumen
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4572671345870018
# Q01279
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial proton-transporting ATP synthase, catalytic core
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.45655709245254994
# Q03265
# ====================================
# ====================================
# ====================================
# ====================================
# cofilin-actin rod
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.4558492519991351
# P18760
# ====================================
# ====================================
# ====================================
# ====================================
# pyruvate kinase complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.45514360300223244
# P52480
# ====================================
# ====================================
# ====================================
# ====================================
# bub1-bub3 complex
# 1
# 0.08114742919489021
# 0.14448293245181432
# 12.323249299719889
# 0.45444013530052885
# Q9WVA3
# ====================================
# ====================================
# ====================================
# ====================================
# GAIT complex
# 4
# 0.32458971677956083
# 0.0017314224021974757
# 12.323249299719889
# 0.014440346674065012
# Q8CGC7
# P19253
# P16858
# Q7TMK9
# ====================================
# ====================================
# ====================================
# ====================================
# Arp2/3 protein complex
# 9
# 0.7303268627540119
# 1.9317601923322058E-6
# 12.323249299719887
# 3.418375644692208E-5
# Q9D898
# P61161
# Q9WV32
# Q9JM76
# Q9CVB6
# Q9CPW4
# Q9R0Q6
# P59999
# Q99JY9
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome core complex, alpha-subunit complex
# 8
# 0.6491794335591217
# 4.981431406443624E-5
# 10.782843137254902
# 6.582605787086217E-4
# O70435
# Q9R1P0
# Q9QUM9
# Q9Z2U1
# P49722
# Q9R1P4
# Q9Z2U0
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic translation initiation factor 3 complex
# 16
# 1.2983588671182433
# 7.904683517382974E-9
# 10.782843137254902
# 1.9617110924237018E-7
# Q99JX4
# Q91WK2
# Q3UGC7
# Q9QZD9
# O70194
# Q9DCH4
# Q9Z1D1
# Q8R1B4
# Q62167
# Q8JZQ9
# P23116
# Q9DBZ5
# Q8QZY1
# P60229
# ====================================
# ====================================
# ====================================
# ====================================
# cytosolic proteasome complex
# 6
# 0.48688457516934125
# 7.452611536637289E-4
# 10.26937441643324
# 0.0069251435968296264
# P54775
# Q9JHR7
# P62196
# O35593
# P62334
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial alpha-ketoglutarate dehydrogenase complex
# 6
# 0.48688457516934125
# 7.452611536637289E-4
# 10.26937441643324
# 0.006893665671389492
# P53395
# O08749
# Q6P3A8
# P50136
# Q9CQX8
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome regulatory particle, base subcomplex
# 12
# 0.9737691503386825
# 1.5463697341259E-6
# 10.26937441643324
# 2.860784008132915E-5
# P54775
# O35226
# Q3TXS7
# P46471
# P62196
# Q8VDM4
# O88685
# P62192
# Q8BJY1
# P62334
# ====================================
# ====================================
# ====================================
# ====================================
# proton-transporting ATP synthase complex, catalytic core F(1)
# 6
# 0.48688457516934125
# 7.452611536637289E-4
# 10.26937441643324
# 0.006862472614052888
# Q9D3D9
# Q03265
# P56480
# Q91VR2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic translation initiation factor 2 complex
# 6
# 0.48688457516934125
# 7.452611536637289E-4
# 10.26937441643324
# 0.006831560575250847
# Q8BJW6
# Q9Z0N1
# Q9Z0N2
# Q99L45
# Q6ZWX6
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial tricarboxylic acid cycle enzyme complex
# 11
# 0.8926217211437922
# 5.811907351614606E-6
# 10.082658517952638
# 9.312780677587184E-5
# Q9D6R2
# P53395
# O08749
# Q6P3A8
# Q9Z2I8
# Q9WUM5
# P50136
# Q9CQX8
# P70404
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial proton-transporting ATP synthase complex, catalytic sector F(1)
# 5
# 0.40573714597445104
# 0.002931811620588513
# 9.858599439775912
# 0.022514100558104246
# Q9D3D9
# Q03265
# P56480
# Q91VR2
# ====================================
# ====================================
# ====================================
# ====================================
# chaperonin-containing T-complex
# 10
# 0.8114742919489021
# 2.1903280166510214E-5
# 9.858599439775912
# 3.0529572012909787E-4
# P80315
# P80314
# P80313
# P42932
# P11983
# P80318
# P80317
# P80316
# ====================================
# ====================================
# ====================================
# ====================================
# SAM complex
# 5
# 0.40573714597445104
# 0.002931811620588513
# 9.858599439775912
# 0.022429461082321897
# Q8BGH2
# Q5U458
# O88441
# P47802
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome core complex
# 19
# 1.541801154702914
# 6.025658912262913E-9
# 9.728881026094648
# 1.513853813142596E-7
# O70435
# P70195
# P99026
# Q9R1P0
# Q9R1P1
# P28063
# Q9R1P4
# Q9R1P3
# Q60692
# O55234
# Q9QUM9
# Q9Z2U1
# P49722
# O09061
# Q9Z2U0
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome regulatory particle
# 23
# 1.866390871482475
# 1.994899786430896E-10
# 9.644282060650346
# 5.7177761484322166E-9
# Q9D8W5
# P54775
# Q3TXS7
# Q9CX56
# P46471
# Q8BG32
# O35593
# Q8VDM4
# P62192
# Q8BJY1
# Q9WVJ2
# P14685
# Q99JI4
# O35226
# P62196
# O88685
# P26516
# P62334
# ====================================
# ====================================
# ====================================
# ====================================
# tricarboxylic acid cycle enzyme complex
# 17
# 1.3795062963131335
# 8.179284015672852E-8
# 9.423661229197561
# 1.7897680614940058E-6
# Q60597
# Q9D6R2
# P53395
# O08749
# Q6P3A8
# Q9Z2I8
# Q9WUM5
# P50136
# Q9CQX8
# P70404
# P97807
# Q9Z2I9
# Q9D2G2
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome accessory complex
# 25
# 2.0286857298722554
# 8.897801461126233E-11
# 9.365669467787114
# 2.5867179961988405E-9
# Q9D8W5
# P54775
# Q3TXS7
# Q9CX56
# P46471
# Q8BG32
# O35593
# Q8VDM4
# P62192
# Q8BJY1
# Q9WVJ2
# P14685
# Q99JI4
# O35226
# P62196
# O88685
# P26516
# P62334
# P97371
# ====================================
# ====================================
# ====================================
# ====================================
# cytosolic small ribosomal subunit
# 45
# 3.6516343137700593
# 3.8745236059136405E-18
# 9.310899470899471
# 1.67758628468814E-16
# P97461
# P62082
# P62281
# Q62167
# P63323
# P62855
# P62858
# P25444
# P63325
# P62852
# P62754
# P97351
# P62908
# Q8BJW6
# Q9CZX8
# P62849
# Q6ZWY3
# P62270
# P14206
# Q9CQR2
# P63276
# P62242
# P62264
# Q9DB27
# Q6ZWN5
# P14131
# P62267
# P62245
# P01942
# P62702
# P60867
# P62983
# P62301
# P62843
# ====================================
# ====================================
# ====================================
# ====================================
# commitment complex
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07306434162852445
# P62320
# P62315
# P26369
# ====================================
# ====================================
# ====================================
# ====================================
# supraspliceosomal complex
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07284158448941308
# Q9EPU0
# Q91VM5
# Q9WV02
# ====================================
# ====================================
# ====================================
# ====================================
# fumarate reductase complex
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07262018149704405
# Q9CQA3
# Q9CZB0
# Q8K2B3
# ====================================
# ====================================
# ====================================
# ====================================
# succinate dehydrogenase complex
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.0724001203409924
# Q9CQA3
# Q9CZB0
# Q8K2B3
# ====================================
# ====================================
# ====================================
# ====================================
# respiratory chain complex II
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07218138885959967
# Q9CQA3
# Q9CZB0
# Q8K2B3
# ====================================
# ====================================
# ====================================
# ====================================
# succinate dehydrogenase complex (ubiquinone)
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07196397503773341
# Q9CQA3
# Q9CZB0
# Q8K2B3
# ====================================
# ====================================
# ====================================
# ====================================
# endoplasmic reticulum chaperone complex
# 12
# 0.9737691503386825
# 9.492490292931464E-6
# 9.242436974789916
# 1.4415834138892188E-4
# Q63886
# Q9JKR6
# Q99KV1
# P20029
# P24369
# P09103
# P08113
# P08003
# Q922R8
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial respiratory chain complex II, succinate dehydrogenase complex (ubiquinone)
# 4
# 0.32458971677956083
# 0.011740560055296065
# 9.242436974789916
# 0.07174786700458706
# Q9CQA3
# Q9CZB0
# Q8K2B3
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome core complex, beta-subunit complex
# 11
# 0.8926217211437922
# 3.5341905732477536E-5
# 8.962363127069011
# 4.826897863462536E-4
# P70195
# P99026
# O55234
# Q9R1P1
# P28063
# Q9R1P3
# Q60692
# O09061
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial pyruvate dehydrogenase complex
# 7
# 0.5680320043642315
# 0.0011988104106305617
# 8.802320928371348
# 0.01029358306174343
# Q8BKZ9
# O08749
# P35486
# Q9D051
# Q8BMF4
# ====================================
# ====================================
# ====================================
# ====================================
# dihydrolipoyl dehydrogenase complex
# 10
# 0.8114742919489021
# 1.3166801199384728E-4
# 8.626274509803922
# 0.001472222002238897
# Q60597
# P53395
# O08749
# Q6P3A8
# Q9D2G2
# P50136
# Q9CQX8
# ====================================
# ====================================
# ====================================
# ====================================
# intercellular canaliculus
# 10
# 0.8114742919489021
# 1.3166801199384728E-4
# 8.626274509803922
# 0.001464177073264914
# Q9JMD3
# Q8VI47
# P21440
# Q9QY30
# P39447
# P28843
# Q80WJ7
# ====================================
# ====================================
# ====================================
# ====================================
# zona pellucida receptor complex
# 13
# 1.0549165795335727
# 1.499365068025243E-5
# 8.531480284421463
# 2.133711827574384E-4
# P80315
# P80314
# P80313
# P42932
# P17879
# P11983
# P80318
# P80317
# P80316
# ====================================
# ====================================
# ====================================
# ====================================
# translation release factor complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2171005731485725
# Q8R050
# Q8BWY3
# ====================================
# ====================================
# ====================================
# ====================================
# concave side of sperm head
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21662237805353157
# Q9CVB6
# Q99JY9
# ====================================
# ====================================
# ====================================
# ====================================
# nuclear proteasome complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21614628491495239
# Q9D8W5
# P62196
# ====================================
# ====================================
# ====================================
# ====================================
# ciliary pocket membrane
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21567227990417398
# Q9WVK4
# Q9QXY6
# ====================================
# ====================================
# ====================================
# ====================================
# ciliary pocket
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21520034931357404
# Q9WVK4
# Q9QXY6
# ====================================
# ====================================
# ====================================
# ====================================
# lamin filament
# 6
# 0.48688457516934125
# 0.0045975012486414255
# 8.215499533146593
# 0.03294336282037078
# P21619
# O55135
# P48678
# P14733
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial isocitrate dehydrogenase complex (NAD+)
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21473047955524746
# Q9D6R2
# P70404
# ====================================
# ====================================
# ====================================
# ====================================
# 1-alkyl-2-acetylglycerophosphocholine esterase complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21426265715970227
# Q61206
# P63005
# ====================================
# ====================================
# ====================================
# ====================================
# methionine adenosyltransferase complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2137968687745725
# Q99LB6
# Q91X83
# ====================================
# ====================================
# ====================================
# ====================================
# fibrinogen complex
# 6
# 0.48688457516934125
# 0.0045975012486414255
# 8.215499533146593
# 0.03282777207363264
# Q8VCM7
# E9PV24
# P11276
# Q8K0E8
# ====================================
# ====================================
# ====================================
# ====================================
# tubulin complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2133331011633478
# P99024
# P68372
# ====================================
# ====================================
# ====================================
# ====================================
# respiratory chain complex III
# 12
# 0.9737691503386825
# 5.502857131432141E-5
# 8.215499533146593
# 7.224718879009295E-4
# Q9D0M3
# Q9CQ69
# Q9CR68
# Q9D855
# Q9CZ13
# Q8R1I1
# Q9DB77
# P00397
# ====================================
# ====================================
# ====================================
# ====================================
# endosome to plasma membrane transport vesicle
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2128713412041198
# P35279
# Q7M6Y3
# ====================================
# ====================================
# ====================================
# ====================================
# tubulobulbar complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21241157588834414
# Q9WV32
# Q99JY9
# ====================================
# ====================================
# ====================================
# ====================================
# oxoglutarate dehydrogenase complex
# 6
# 0.48688457516934125
# 0.0045975012486414255
# 8.215499533146593
# 0.03271298965379476
# Q60597
# O08749
# Q9D2G2
# Q9CQX8
# ====================================
# ====================================
# ====================================
# ====================================
# isocitrate dehydrogenase complex (NAD+)
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21195379231961928
# Q9D6R2
# P70404
# ====================================
# ====================================
# ====================================
# ====================================
# eukaryotic translation elongation factor 1 complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2114979777124803
# O70251
# P57776
# ====================================
# ====================================
# ====================================
# ====================================
# myosin II filament
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21104411939120887
# Q8VDD5
# Q61879
# ====================================
# ====================================
# ====================================
# ====================================
# discoidal high-density lipoprotein particle
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21059220478865812
# Q00623
# P08226
# ====================================
# ====================================
# ====================================
# ====================================
# CRD-mediated mRNA stability complex
# 6
# 0.48688457516934125
# 0.0045975012486414255
# 8.215499533146593
# 0.032599007111447045
# P62960
# O70133
# Q8VEK3
# Q7TMK9
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrion-derived vesicle
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.21014222144509262
# Q9EQH3
# Q8K1M6
# ====================================
# ====================================
# ====================================
# ====================================
# TAP complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20969415700704336
# P27773
# P21958
# ====================================
# ====================================
# ====================================
# ====================================
# muscle cell projection membrane
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20924799922617732
# Q9CVB6
# Q9R0Q6
# ====================================
# ====================================
# ====================================
# ====================================
# muscle cell projection
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.2088037359581812
# Q9CVB6
# Q9R0Q6
# ====================================
# ====================================
# ====================================
# ====================================
# signal recognition particle receptor complex
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20836135516165963
# Q9DBG7
# P47758
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial respiratory chain complex III
# 12
# 0.9737691503386825
# 5.502857131432141E-5
# 8.215499533146593
# 7.178406578502825E-4
# Q9D0M3
# Q9CQ69
# Q9CR68
# Q9D855
# Q9CZ13
# Q8R1I1
# Q9DB77
# P00397
# ====================================
# ====================================
# ====================================
# ====================================
# endocytic vesicle lumen
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20792084489704724
# P09528
# P29391
# ====================================
# ====================================
# ====================================
# ====================================
# peripheral region of growth cone
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20748219332553447
# Q9JM76
# Q9CVB6
# ====================================
# ====================================
# ====================================
# ====================================
# Schwann cell microvillus
# 3
# 0.24344228758467062
# 0.04832754773282719
# 8.215499533146593
# 0.20704538870800704
# P26040
# P45376
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome regulatory particle, lid subcomplex
# 9
# 0.7303268627540119
# 4.907066824222016E-4
# 8.215499533146591
# 0.004824097095310049
# Q9D8W5
# Q9CX56
# Q8BG32
# O35593
# Q9WVJ2
# P14685
# ====================================
# ====================================
# ====================================
# ====================================
# cytosolic ribosome
# 108
# 8.763922353048143
# 1.2817149864279086E-33
# 8.101395372964001
# 1.0433159989523177E-31
# P62918
# P97461
# Q9CXW4
# P35979
# P62717
# P19253
# P62082
# P62281
# P12970
# P14115
# Q62167
# P62751
# P63323
# P35980
# O09167
# P62911
# P47955
# P47911
# P25444
# P63325
# P62830
# P62754
# P97351
# Q9CR57
# P62849
# Q6ZWY3
# Q9JJI8
# P14206
# Q9CPR4
# P62242
# Q9DB27
# P14131
# P62245
# P84099
# P61358
# P01942
# P62889
# P60867
# P61514
# P62843
# Q9CZM2
# P53026
# Q6ZWV3
# P99027
# P67984
# P62855
# P62858
# P62852
# P62908
# Q8BJW6
# P51410
# Q9CZX8
# P14869
# P62270
# P14148
# Q99N96
# Q9CQR2
# P63276
# P62264
# Q6ZWN5
# P62267
# Q9D8E6
# P47962
# Q6ZWV7
# P62702
# P47963
# P62900
# Q8BP67
# P27659
# P62983
# P62301
# ====================================
# ====================================
# ====================================
# ====================================
# proteasome complex
# 64
# 5.193435468472973
# 2.046980349194301E-20
# 8.087132352941177
# 1.1901728601744008E-18
# Q9D8W5
# P54775
# O70435
# P99026
# P46471
# Q9R1P0
# Q8BG32
# O35593
# Q8VDM4
# Q9R1P1
# Q9WUP7
# P28063
# Q9R1P4
# Q9R1P3
# Q9WVJ2
# Q6PDI5
# O35226
# Q5SSW2
# Q9JHR7
# P62196
# O55234
# Q9Z2U1
# P26516
# P62334
# O09061
# Q9Z2U0
# P97371
# Q3TXS7
# P70195
# Q9CX56
# Q9JMA1
# P54728
# P62192
# Q8BJY1
# Q60692
# P14685
# Q01853
# Q99JI4
# Q9QUM9
# P49722
# O88685
# Q8CDN6
# ====================================
# ====================================
# ====================================
# ====================================
# polysomal ribosome
# 34
# 2.759012592626267
# 2.833853309330091E-11
# 7.973867193936399
# 8.480722771304022E-10
# P62918
# P53026
# Q9CXW4
# O70133
# P62717
# Q91WK2
# Q9JJI8
# P12970
# Q9CQR2
# P62267
# P58252
# P35980
# P84099
# P62855
# P62911
# P62889
# P62900
# Q8BP67
# P62858
# P47911
# Q8K1R3
# Q6P542
# ====================================
# ====================================
# ====================================
# ====================================
# pyruvate dehydrogenase complex
# 8
# 0.6491794335591217
# 0.0018281887127327304
# 7.702030812324931
# 0.015185159307800435
# Q8BKZ9
# O08749
# P35486
# Q9D051
# Q8BMF4
# ====================================
# ====================================
# ====================================
# ====================================
# cytosolic large ribosomal subunit
# 61
# 4.949993180888303
# 4.80310084356651E-18
# 7.676778252284521
# 1.9947571870730302E-16
# P62918
# P53026
# Q9CXW4
# P35979
# Q6ZWV3
# P99027
# P62717
# P19253
# P12970
# P14115
# P67984
# P62751
# P63323
# P35980
# O09167
# P62911
# P47955
# P47911
# P62830
# P51410
# Q9CR57
# P14869
# Q9JJI8
# P14148
# Q9CPR4
# Q99N96
# P84099
# Q9D8E6
# P47962
# P61358
# Q6ZWV7
# P62889
# P47963
# P62900
# Q8BP67
# P27659
# P61514
# Q9CZM2
# ====================================
# ====================================
# ====================================
# ====================================
# tubular endosome
# 5
# 0.40573714597445104
# 0.017746042647475133
# 7.393949579831933
# 0.10230367361929717
# Q9EQH3
# Q9D8U8
# P40336
# ====================================
# ====================================
# ====================================
# ====================================
# endoplasmic reticulum tubular network membrane
# 5
# 0.40573714597445104
# 0.017746042647475133
# 7.393949579831933
# 0.10201468019099406
# Q6PA06
# Q99P72
# Q91YH5
# ====================================
# ====================================
# ====================================
# ====================================
# flotillin complex
# 10
# 0.8114742919489021
# 7.354411814318779E-4
# 7.393949579831933
# 0.006865242221164547
# P26231
# Q62417
# P30999
# O08917
# Q02248
# Q9WUM4
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial proton-transporting ATP synthase complex
# 20
# 1.6229485838978042
# 1.684526328911479E-6
# 7.393949579831933
# 3.0607241779775536E-5
# Q06185
# P97450
# Q78IK2
# P56135
# Q9CQQ7
# Q9D3D9
# Q9CPQ8
# Q03265
# Q9DCX2
# P56480
# Q91VR2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial proton-transporting ATP synthase complex, coupling factor F(o)
# 12
# 0.9737691503386825
# 2.9845452347591455E-4
# 7.188562091503268
# 0.003067449269058011
# Q06185
# P97450
# P56135
# Q9CQQ7
# Q9CPQ8
# Q9DCX2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# COPI vesicle coat
# 12
# 0.9737691503386825
# 2.9845452347591455E-4
# 7.188562091503268
# 0.003052034951123046
# Q9QZE5
# Q8CIE6
# Q9QXK3
# Q9JIF7
# O55029
# O89079
# Q5XJY5
# ====================================
# ====================================
# ====================================
# ====================================
# respiratory chain complex I
# 50
# 4.057371459744511
# 1.6163171710287605E-13
# 7.147484593837535
# 5.482009071739213E-12
# Q62425
# P03888
# P03921
# Q8K3J1
# Q9ERS2
# Q9DCJ5
# Q9CR61
# Q7TMF3
# Q91WD5
# Q99LY9
# Q9D8B4
# Q9CQH3
# Q9D6J6
# Q9DCT2
# Q9D6J5
# Q9CQJ8
# Q91YT0
# Q9CPP6
# Q9CQZ5
# P52503
# Q9CQ54
# Q9CQ75
# Q9CXZ1
# Q9CQC7
# Q9DC69
# Q91VD9
# Q9DCS9
# Q3UIU2
# Q99LC3
# ====================================
# ====================================
# ====================================
# ====================================
# NADH dehydrogenase complex
# 50
# 4.057371459744511
# 1.6163171710287605E-13
# 7.147484593837535
# 5.3921400705631604E-12
# Q62425
# P03888
# P03921
# Q8K3J1
# Q9ERS2
# Q9DCJ5
# Q9CR61
# Q7TMF3
# Q91WD5
# Q99LY9
# Q9D8B4
# Q9CQH3
# Q9D6J6
# Q9DCT2
# Q9D6J5
# Q9CQJ8
# Q91YT0
# Q9CPP6
# Q9CQZ5
# P52503
# Q9CQ54
# Q9CQ75
# Q9CXZ1
# Q9CQC7
# Q9DC69
# Q91VD9
# Q9DCS9
# Q3UIU2
# Q99LC3
# ====================================
# ====================================
# ====================================
# ====================================
# mitochondrial respiratory chain complex I
# 50
# 4.057371459744511
# 1.6163171710287605E-13
# 7.147484593837535
# 5.305170069425044E-12
# Q62425
# P03888
# P03921
# Q8K3J1
# Q9ERS2
# Q9DCJ5
# Q9CR61
# Q7TMF3
# Q91WD5
# Q99LY9
# Q9D8B4
# Q9CQH3
# Q9D6J6
# Q9DCT2
# Q9D6J5
# Q9CQJ8
# Q91YT0
# Q9CPP6
# Q9CQZ5
# P52503
# Q9CQ54
# Q9CQ75
# Q9CXZ1
# Q9CQC7
# Q9DC69
# Q91VD9
# Q9DCS9
# Q3UIU2
# Q99LC3
# ====================================
# ====================================
# ====================================
# ====================================
# proton-transporting ATP synthase complex
# 21
# 1.7040960130926943
# 2.4664663947349623E-6
# 7.041856742697079
# 4.289965054090298E-5
# Q06185
# P97450
# Q78IK2
# P56135
# Q9CQQ7
# Q9D3D9
# Q9CPQ8
# Q03265
# Q9DCX2
# P56480
# Q91VR2
# Q9DB20
# ====================================
# ====================================
# ====================================
# ====================================
# microbody lumen
# 28
# ...
# ====================================
# ====================================
# PUMA-BCL-xl complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# BIM-BCL-2 complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# BIM-BCL-xl complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# ESC/E(Z) complex
# 16
# 1.2983588671182433
# 0.6273043060513699
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# HOPS complex
# 11
# 0.8926217211437922
# 0.9999999999276646
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# checkpoint clamp complex
# 5
# 0.40573714597445104
# 1.0000000000054579
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# meiotic cohesin complex
# 8
# 0.6491794335591217
# 1.000000000006531
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# mitotic cohesin complex
# 5
# 0.40573714597445104
# 1.0000000000054579
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# U4/U6 snRNP
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# NMS complex
# 10
# 0.8114742919489021
# 0.9999999999528182
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# RES complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# Bcl-2 family protein complex
# 9
# 0.7303268627540119
# 0.9999999999705337
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin E2-CDK2 complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin E1-CDK2 complex
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin D2-CDK6 complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin D3-CDK4 complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# primary lysosome
# 20
# 1.6229485838978042
# 0.3961307184322917
# 0.0
# 0.887803977984266
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# granulocyte macrophage colony-stimulating factor receptor complex
# 5
# 0.40573714597445104
# 1.0000000000054579
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cytosolic tRNA wobble base thiouridylase complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# stereocilia ankle link complex
# 6
# 0.48688457516934125
# 0.9999999999896062
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# follicle-stimulating hormone complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# stereocilia ankle link
# 6
# 0.48688457516934125
# 0.9999999999896062
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# gamma DNA polymerase complex
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# stereocilia tip link
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cytoplasmic side of lysosomal membrane
# 12
# 0.9737691503386825
# 0.9999999999846395
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin D2-CDK4 complex
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin D1-CDK4 complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin B1-CDK1 complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin A2-CDK2 complex
# 4
# 0.32458971677956083
# 1.000000000015596
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cyclin A1-CDK2 complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# stereocilia coupling link
# 7
# 0.5680320043642315
# 0.9999999999632864
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# clathrin-sculpted glutamate transport vesicle
# 7
# 0.5680320043642315
# 0.9999999999632864
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# clathrin-sculpted vesicle
# 9
# 0.7303268627540119
# 0.9999999999705337
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# polycystin complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# nucleolar chromatin
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# Mre11 complex
# 5
# 0.40573714597445104
# 1.0000000000054579
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# inward rectifier potassium channel complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cytoplasmic side of late endosome membrane
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# pigment granule membrane
# 9
# 0.7303268627540119
# 0.9999999999705337
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# inner dynein arm
# 12
# 0.9737691503386825
# 0.9999999999846395
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# perinucleolar chromocenter
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cytoplasmic side of rough endoplasmic reticulum membrane
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# cytoplasmic side of endoplasmic reticulum membrane
# 10
# 0.8114742919489021
# 0.9999999999528182
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# tenascin complex
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# Las1 complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# Lewy neurite
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# RNA polymerase I complex
# 13
# 1.0549165795335727
# 0.6173202204906333
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# semaphorin receptor complex
# 9
# 0.7303268627540119
# 0.9999999999705337
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# chromocenter
# 17
# 1.3795062963131335
# 0.6337358394001791
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# BRCA2-BRAF35 complex
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# nucleolus organizer region
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# postsynaptic endocytic zone cytoplasmic component
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# stereocilium membrane
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# lumenal side of Golgi membrane
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# meprin A complex
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# hippocampal mossy fiber
# 6
# 0.48688457516934125
# 0.9999999999896062
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# terminal loop
# 1
# 0.08114742919489021
# 0.9999999999763732
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# TORC2 complex
# 11
# 0.8926217211437922
# 0.9999999999276646
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# mesaxon
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# TORC1 complex
# 8
# 0.6491794335591217
# 1.000000000006531
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# junctional sarcoplasmic reticulum membrane
# 4
# 0.32458971677956083
# 1.000000000015596
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# nuclear membrane microtubule tethering complex
# 11
# 0.8926217211437922
# 0.9999999999276646
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# postsynaptic specialization of symmetric synapse
# 3
# 0.24344228758467062
# 1.0000000000247955
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================
# ====================================
# ====================================
# autosome
# 2
# 0.16229485838978042
# 1.0000000000327207
# 0.0
# 1.0
# Error Reading proeint list
# ====================================
# ====================================

# %%
parsedData.columns=['complex_name','protien_count','expected','pValue','fold_enrichment','fdr','protien_list']
parsedData.pValue=[float(x) for x in parsedData.pValue]
parsedData.to_csv('GODBB_raw_data.csv', index=False)
print(parsedData.shape)
parsedData.head()
# Out:
# (2035, 7)
#                                         complex_name  protien_count  \
# 0      fatty acid beta-oxidation multienzyme complex              2
# 1                       gamma-catenin-TCF7L2 complex              1
# 2  mitochondrial proton-transporting ATP synthase...              2
# 3                                late endosome lumen              2
# 4                                          ectoplasm              1
#
#               expected    pValue  fold_enrichment       fdr      protien_list
# 0  0.16229485838978042  0.030501        12.323249  0.158746  [Q99JY0, Q8BMS1]
# 1  0.08114742919489021  0.144483        12.323249  0.491677          [Q02257]
# 2  0.16229485838978042  0.030501        12.323249  0.158341  [Q9DCX2, Q9DB20]
# 3  0.16229485838978042  0.030501        12.323249  0.157938  [P16858, P63017]
# 4  0.08114742919489021  0.144483        12.323249  0.490856          [Q8VCB3]

# %%
parsedData=parsedData[(parsedData.protien_count>=5)& (parsedData.fold_enrichment>2)& (parsedData.pValue<0.001)& 
                      (parsedData.fdr<0.01)]
parsedData=parsedData.reset_index(drop=True)
print(parsedData.shape)
parsedData.head()
# Out:
# (160, 7)
#                                         complex_name  protien_count  \
# 0  eukaryotic translation initiation factor 3 com...              8
# 1      aminoacyl-tRNA synthetase multienzyme complex             12
# 2                             Arp2/3 protein complex              9
# 3     proteasome core complex, alpha-subunit complex              8
# 4  eukaryotic translation initiation factor 3 com...             16
#
#              expected        pValue  fold_enrichment           fdr  \
# 0  0.6491794335591217  7.383767e-06        12.323249  1.147020e-04
# 1  0.9737691503386825  3.555710e-08        12.323249  8.130192e-07
# 2  0.7303268627540119  1.931760e-06        12.323249  3.418376e-05
# 3  0.6491794335591217  4.981431e-05        10.782843  6.582606e-04
# 4  1.2983588671182433  7.904684e-09        10.782843  1.961711e-07
#
#                                         protien_list
# 0  [Q99JX4, Q91WK2, Q9QZD9, O70194, Q9DCH4, P2311...
# 1  [Q68FL6, Q8CGC7, Q8BML9, Q8BMJ2, Q8R010, Q9D1M...
# 2  [Q9D898, P61161, Q9WV32, Q9JM76, Q9CVB6, Q9CPW...
# 3  [O70435, Q9R1P0, Q9QUM9, Q9Z2U1, P49722, Q9R1P...
# 4  [Q99JX4, Q91WK2, Q3UGC7, Q9QZD9, O70194, Q9DCH...

# %% [markdown]
# # Read utmb data

# %%
# utmb_data= pd.read_csv("compare.csv")[["Portien","rateconst"]]
utmb_data= pd.read_csv("Analyzed_Proteins_and_Their_Rates.csv")[["Proteins"," RateConstant"]]
utmb_data.columns=["protiens","rateconst"]

utmb_list= pd.read_csv("Protein_List.utmb.0518_2022.csv")[["Entry","Entry name","Gene names"]]
utmb_data=utmb_data.merge(utmb_list,left_on=["protiens"],right_on=["Entry name"])[["Entry","Entry name",
                                                                                  "rateconst","Gene names"]]
utmb_data=utmb_data.reset_index(drop=True)

# %% [markdown]
# # Merge the data

# %%
#search
found_list={}

for i in range(utmb_data.shape[0]): 
    
    for j in range(parsedData.shape[0]):
        
        temp=list(parsedData[ "protien_list"][j])
        temp=[x.strip() for x in temp]
        
        if((utmb_data["Entry"][i]).strip() in temp):
            
            
            if( (parsedData["complex_name"][j]) in found_list.keys()):
                
                found_list[parsedData["complex_name"][j]]["protiens"].append(utmb_data["Entry"][i])
                found_list[parsedData["complex_name"][j]]["protiens_name"].append(utmb_data["Entry name"][i])
                found_list[parsedData["complex_name"][j]]["k"].append(float(utmb_data["rateconst"][i]))
                
            else:
                found_list[(parsedData["complex_name"][j])]={"complex_name":parsedData["complex_name"][j],
                                                  "protiens":[utmb_data["Entry"][i]],
                                                  "protiens_name":[utmb_data["Entry name"][i]],
                                                  "k":[ float(utmb_data["rateconst"][i])]}

# %%
def prepare_data(found_list, droplist):
    df=pd.DataFrame(found_list)
    df=df.transpose()
    print(df.shape)
    df=df.drop(index = droplist)#'late endosome membrane',

    df["pc"]=[len(k) for k in df.k]
    df=df[df.pc<100]
    df=df[df.pc>=5]
    df=df.sort_values(by=['pc'])
    df=df.reset_index(drop=True)
    print(df.shape)
    
    return df
droplist=['protein-lipid complex','blood microparticle',"endocytic vesicle membrane",
                        'lipoprotein particle','high-density lipoprotein particle','plasma lipoprotein particle',
                       'triglyceride-rich plasma lipoprotein particle',
                       'very-low-density lipoprotein particle','secondary lysosome','phagocytic vesicle',
                       'phagocytic vesicle membrane','U5 snRNP','MHC class I peptide loading complex',
                       'extrinsic component of organelle membrane','microbody lumen','peroxisomal matrix']

for i in ['protein-lipid complex', 'blood microparticle', 'endocytic vesicle membrane', 'lipoprotein particle', 'high-density lipoprotein particle', 'plasma lipoprotein particle', 'triglyceride-rich plasma lipoprotein particle', 'very-low-density lipoprotein particle', 'secondary lysosome', 'phagocytic vesicle', 'phagocytic vesicle membrane', 'U5 snRNP', 'MHC class I peptide loading complex', 'extrinsic component of organelle membrane']:
    droplist.remove(i)
df=prepare_data(found_list, droplist)
df.head(5)
# Out:
# (160, 4)
# (137, 5)
#                                         complex_name  \
# 0  eukaryotic translation initiation factor 2 com...
# 1  proton-transporting ATP synthase complex, cata...
# 2                       cytosolic proteasome complex
# 3     proteasome regulatory particle, lid subcomplex
# 4                dihydrolipoyl dehydrogenase complex
#
#                                            protiens  \
# 0          [Q8BJW6, Q6ZWX6, Q99L45, Q9Z0N1, Q9Z0N2]
# 1          [Q03265, P56480, Q9D3D9, Q91VR2, Q9DB20]
# 2          [Q9JHR7, P62334, P54775, P62196, O35593]
# 3  [Q8BG32, Q9D8W5, Q9WVJ2, O35593, P14685, Q9CX56]
# 4  [O08749, P53395, P50136, Q6P3A8, Q60597, Q9D2G2]
#
#                                        protiens_name  \
# 0  [EIF2A_MOUSE, IF2A_MOUSE, IF2B_MOUSE, IF2G_MOU...
# 1  [ATPA_MOUSE, ATPB_MOUSE, ATPD_MOUSE, ATPG_MOUS...
# 2  [IDE_MOUSE, PRS10_MOUSE, PRS6B_MOUSE, PRS8_MOU...
# 3  [PSD11_MOUSE, PSD12_MOUSE, PSD13_MOUSE, PSDE_M...
# 4  [DLDH_MOUSE, ODB2_MOUSE, ODBA_MOUSE, ODBB_MOUS...
#
#                                                    k  pc
# 0  [0.369833, 0.244568, 0.359971, 0.370645, 0.312...   5
# 1  [0.144409, 0.127794, 0.135125, 0.100345, 0.116...   5
# 2  [0.501454, 0.420918, 0.271184, 0.368021, 0.313...   5
# 3  [0.682711, 0.356529, 0.275296, 0.313562, 0.390...   6
# 4  [0.127032, 0.160933, 0.257309, 0.062406, 0.413...   6

# %% [markdown]
# # Draw the chart

# %%
def drawboxplot(df):
    compd=pd.DataFrame()

    for i in range(df.shape[0]):
    # for i in range(400):
        if(len(list(df['k'][i])) >=5):
            perc= pd.DataFrame()
            perc["k"]=df['k'][i]
    #         perc["complex_name"]=df['complex_name'][i] + " ("+str(i)+"  "+str(len(list(df['k'][i]))) +")"
            perc["complex_name"]=df['complex_name'][i] + " ("+str(len(list(df['k'][i]))) +")"
            compd=pd.concat([compd,perc])

    # fig = plt.gcf()
    fig, ax = plt.subplots(1)

    # Change seaborn plot size
    fig.set_size_inches(9, 100)

    sns.boxplot(x="k", y="complex_name", data=compd,orient ='h')
    # sns.swarmplot(x="k", y="name", data=compd,orient='h', color=".25")
    plt.xlabel('')
    plt.ylabel('')
    # sns.swarmplot(x="name", y="k", data=compd, color=".25")        
drawboxplot(df)

# %%
# similar_comp=[]
# for index in range(5,101):
#     temp=df[df.pc==index]
#     temp=temp.reset_index(drop=True)
#     for i in range(temp.shape[0]):
#         temp_s=[]
#         for j in range(temp.shape[0]): 
#             if(temp.k[i]==temp.k[j]):
#                 if temp.complex_name[i] not in temp_s:
#                     temp_s.append(temp.complex_name[i] )
#         similar_comp.append(temp_s)

# %%
# similar_comp=[]
# for index in range(5,101):
#     temp=df[df.pc==index]
#     temp=temp.reset_index(drop=True)
#     for i in range(temp.shape[0]):
#         temp_s=[]
#         temp_vis=[]
#         for j in range(i+1,temp.shape[0]):  
#             if temp.complex_name[j] in similar_comp: break
#             if(temp.k[i]==temp.k[j]):
#                 similar_comp.append(temp.complex_name[j] )

# %%
df=prepare_data(found_list, droplist )
similar_comp=[]
namedict={}
for index in range(5,101):
    temp=df[df.pc==index]
    temp=temp.reset_index(drop=True)
    for i in range(temp.shape[0]):
        temp_s=[]
        temp_vis=[]
        if temp.complex_name[i] in similar_comp: break
        for j in range(i+1,temp.shape[0]):             
            if(temp.k[i]==temp.k[j]):
                similar_comp.append(temp.complex_name[j] ) 
                if(temp.complex_name[i] not in namedict):
                    namedict[temp.complex_name[i]]=[temp.complex_name[i],temp.complex_name[j]]
                else:namedict[temp.complex_name[i]].append(temp.complex_name[j])
            elif ( len(set(temp.k[i]).intersection(set(temp.k[j])))  / len(set(temp.k[i]) .union(set(temp.k[j]))))>=0.8:
                similar_comp.append(temp.complex_name[j] ) 
                if(temp.complex_name[i] not in namedict):
                    namedict[temp.complex_name[i]]=[temp.complex_name[i],temp.complex_name[j]]
                else:namedict[temp.complex_name[i]].append(temp.complex_name[j])
# Out:
# (160, 4)
# (137, 5)

# %%
len(similar_comp)
# Out:
# 18

# %%
df=prepare_data(found_list, droplist + similar_comp)#'late endosome membrane',
print(df.shape)
df.head(5)
# Out:
# (160, 4)
# (119, 5)
# (119, 5)
#                                         complex_name  \
# 0  proton-transporting ATP synthase complex, cata...
# 1  eukaryotic translation initiation factor 2 com...
# 2                       cytosolic proteasome complex
# 3     proteasome regulatory particle, lid subcomplex
# 4                                  flotillin complex
#
#                                            protiens  \
# 0          [Q03265, P56480, Q9D3D9, Q91VR2, Q9DB20]
# 1          [Q8BJW6, Q6ZWX6, Q99L45, Q9Z0N1, Q9Z0N2]
# 2          [Q9JHR7, P62334, P54775, P62196, O35593]
# 3  [Q8BG32, Q9D8W5, Q9WVJ2, O35593, P14685, Q9CX56]
# 4  [Q9WUM4, P26231, Q02248, P30999, O08917, Q62417]
#
#                                        protiens_name  \
# 0  [ATPA_MOUSE, ATPB_MOUSE, ATPD_MOUSE, ATPG_MOUS...
# 1  [EIF2A_MOUSE, IF2A_MOUSE, IF2B_MOUSE, IF2G_MOU...
# 2  [IDE_MOUSE, PRS10_MOUSE, PRS6B_MOUSE, PRS8_MOU...
# 3  [PSD11_MOUSE, PSD12_MOUSE, PSD13_MOUSE, PSDE_M...
# 4  [COR1C_MOUSE, CTNA1_MOUSE, CTNB1_MOUSE, CTND1_...
#
#                                                    k  pc
# 0  [0.144409, 0.127794, 0.135125, 0.100345, 0.116...   5
# 1  [0.369833, 0.244568, 0.359971, 0.370645, 0.312...   5
# 2  [0.501454, 0.420918, 0.271184, 0.368021, 0.313...   5
# 3  [0.682711, 0.356529, 0.275296, 0.313562, 0.390...   6
# 4  [0.118276, 0.61752, 0.419599, 0.678721, 0.3070...   6

# %%
namedict
# Out:
# {'proton-transporting ATP synthase complex, coupling factor F(o)': ['proton-transporting ATP synthase complex, coupling factor F(o)',
#   'mitochondrial proton-transporting ATP synthase complex, coupling factor F(o)'],
#  'mitochondrial respiratory chain complex III': ['mitochondrial respiratory chain complex III',
#   'respiratory chain complex III'],
#  'respiratory chain complex IV': ['respiratory chain complex IV',
#   'mitochondrial respiratory chain complex IV'],
#  'proton-transporting ATP synthase complex': ['proton-transporting ATP synthase complex',
#   'mitochondrial proton-transporting ATP synthase complex'],
#  'integral component of mitochondrial inner membrane': ['integral component of mitochondrial inner membrane',
#   'intrinsic component of mitochondrial inner membrane'],
#  'microbody membrane': ['microbody membrane', 'peroxisomal membrane'],
#  'mitochondrial ribosome': ['mitochondrial ribosome', 'organellar ribosome'],
#  'integral component of mitochondrial membrane': ['integral component of mitochondrial membrane',
#   'intrinsic component of mitochondrial membrane'],
#  'extracellular exosome': ['extracellular exosome', 'extracellular vesicle'],
#  'contractile actin filament bundle': ['contractile actin filament bundle',
#   'stress fiber'],
#  'membrane coat': ['membrane coat',
#   'coated vesicle membrane',
#   'coated membrane'],
#  'respiratory chain complex I': ['respiratory chain complex I',
#   'mitochondrial respiratory chain complex I',
#   'NADH dehydrogenase complex'],
#  'mitochondrial respirasome': ['mitochondrial respirasome',
#   'respirasome',
#   'respiratory chain complex'],
#  'outer membrane': ['outer membrane', 'organelle outer membrane'],
#  'microbody': ['microbody', 'peroxisome']}

# %%
drawboxplot(df)
